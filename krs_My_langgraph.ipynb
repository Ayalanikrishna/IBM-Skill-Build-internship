# %% [markdown]
# # STEP 0: Install dependencies

# %%
# !pip install -qU google-generativeai==0.8.5 google-ai-generativelanguage==0.6.15 \
langgraph langchain langchain-google-genai openai

# %% [markdown]
# # STEP 1: Imports and secure API key input

# %%
import os
import getpass
from langgraph.graph import StateGraph, END
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage

# %% [markdown]
# # Secure Gemini API Key input

# %%
os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google API Key ")
# Out:
# Enter your Google API Key ··········

# %% [markdown]
# # STEP 2: Initialize Gemini 1.5 Flash

# %%
llm = ChatGoogleGenerativeAI(model="models/gemini-1.5-flash-latest",temperature=0.2)

# %% [markdown]
# # STEP 3: Node to ask user for symptom

# %%
def get_symptom(state: dict) -> dict:
  symptom = input("Welcome to XYZ Hospital,Please enter ur symptom")
  state['symptom'] = symptom
  return state

# %% [markdown]
# # STEP 4: Node to classify the symptom

# %%
def classify_symptom(state: dict) -> dict:
  prompt = (
      "You r helpful medical assistant. Classify the symptoms below into of the categories:\n"
      "-General\n -Emergency\n -mental health\n \n"
      f"Symptom: {state['symptom']}\n"
      "Respond with only one word : General, Emergency or Mental Health"
      "#Example : input : I have fever : Output : General"
  )
  response = llm.invoke(prompt)
  category= response.content.strip()
  print(f"LLM classified the symptom as {category}") #debug
  state['category'] = category # Corrected key to lowercase 'category'
  return state

# %% [markdown]
# # STEP 5: Router logic to route to the correct node

# %%
def symptom_router(state: dict) -> str: # Return type should be string
  cat = state["category"].lower() # Call lower as a function
  if "general" in cat :
    return "general"
  elif "emergency" in cat:
    return "emergency"
  elif "mental" in cat:
    return "mental_health"
  else:
    return "general"

# %% [markdown]
# # STEP 6: Category-specific response nodes

# %%
def general_node(state: dict) -> dict:
  state["answer"] = f" '{state['symptom']}' seems general : Directing u to general ward for consulting a doc"
  return state

def emergency_node(state: dict) -> dict:
  state["answer"] = f" '{state['symptom']}' seems medical emergency : seeking immediate help"
  return state

def mental_health_node(state: dict) -> dict:
  state["answer"] = f" '{state['symptom']}' seems mental issue : talk to our counsellor"
  return state

# %% [markdown]
# # STEP 7: Build LangGraph

# %%
builder = StateGraph(dict)
builder.set_entry_point("get_symptom")
builder.add_node("get_symptom", get_symptom)
builder.add_node("classify", classify_symptom)
builder.add_node("general", general_node)
builder.add_node("emergency", emergency_node)
builder.add_node("mental_health", mental_health_node)


builder.add_edge("get_symptom","classify")
builder.add_conditional_edges("classify",symptom_router,{
    "general":"general",
    "emergency":"emergency",
    "mental_health":"mental_health"
})
builder.add_edge("general",END)
builder.add_edge("emergency",END)
builder.add_edge("mental_health",END)

# %% [markdown]
# # STEP 8: Compile and invoke the graph

# %%
graph = builder.compile()
final_state = graph.invoke({})
print("final output \n")
print (final_state["answer"])
# Out:
# Welcome to XYZ Hospital,Please enter ur symptom high fever
# LLM classified the symptom as Emergency
# final output
#
#  ' high fever' seems medical emergency : seeking immediate help
